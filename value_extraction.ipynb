# %%
import pandas as pd

# %%
df = pd.read_spss("data/EUProfiler_parties.sav")
df.head()
# Out:
#    PARTY COUNTRY                             LEGEND PARTY_FO  \
# 0    3.0      at  Kommunistische Partei Osterreichs   C9333A
# 1    6.0      at        Osterreichische Volkspartei   2651A8
# 2    8.0      at         Bundnis Zukunft Osterreich   999999
# 3    9.0      at                         Die Grunen   339933
# 4   10.0      at   Freiheitliche Partei Osterreichs   999999
#
#                          PARTY_FN  AVERAG_X  AVERAG_Y  LIBERAL  ECONOMIC  \
# 0      Dark red_GUE-NGL, far left -1.333333 -0.428571     96.0      20.0
# 1  Dark blue_EPP-ED, centre-right  0.600000  1.428571     25.0      33.0
# 2      Grey_NA, all other parties  0.666667 -0.285714     29.0      57.0
# 3        Dark green_G-EFA, greens -1.388889  1.428571     93.0      16.0
# 4      Grey_NA, all other parties  0.611111 -1.000000     21.0      57.0
#
#    REST_FIN  ...  SE_29  SE_30  SI_29  SI_30 SK_29 SK_30 TR_29 TR_30 WALE_29  \
# 0      14.0  ...    NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN     NaN
# ...
