# %%
import pandas as pd

# %%
df_parties = pd.read_json("data/euandi_2019_data/euandi_2019_parties.jsonl", lines=True)
df_questionnaire = pd.read_json("data/euandi_2019_data/euandi_2019_questionnaire.jsonl", lines=True)

# %%
df_parties.head()
# Out:
#   party_name                              full_party_name  euro_party  \
# 0     Grünen                                   Die Grünen  Greens/EFA
# 1      Linke                                    Die Linke     GUE/NGL
# 2        CDU  Christlich Demokratische Union Deutschlands         EPP
# 3        AfD                  Alternative für Deutschland          ID
# 4        SPD      Sozialdemokratische Partei Deutschlands         S&D
#
#   country_iso                                        statement_1  \
# 0          de  {'position': 'Allen Menschen in Europa wollen ...
# 1          de  {'position': 'DIE LINKE will soziale Sicherhei...
# 2          de  {'position': 'Starke Schultern tragen mehr als...
# 3          de  {'position': 'Die AfD wendet sich gegen eine A...
# 4          de  {'position': 'Es gilt das alte soziale Verspre...
#
#                                          statement_2  \
# 0  {'position': ' In Italien, Spanien und Grieche...
# ...

# %%
df_questionnaire["statement"][0]['en']
# Out:
# 'Social programmes should be maintained even at the cost of higher taxes.'

# %%
df_questionnaire['statement_en'] = df_questionnaire['statement'].str['en']

# %%
df_questionnaire["statement_en"]
# Out:
# 0     Social programmes should be maintained even at...
# 1     The state should provide stronger financial su...
# 2     The European Union should rigorously punish Me...
# 3     Asylum-seekers should be distributed proportio...
# 4     Immigration into Europe should be made more re...
# 5     Immigrants from outside Europe should be requi...
# 6     The legalisation of same sex marriages is a go...
# 7     The legalisation of the personal use of soft d...
# 8                       Euthanasia should be legalised.
# 9     Government spending should be reduced in order...
# 10    The EU should acquire its own tax raising powers.
# 11    Bank and stock market gains should be taxed mo...
# 12    The promotion of public transport should be fo...
# 13    Renewable sources of energy (e.g. solar or win...
# 14    Restrictions of personal privacy on the Intern...
# 15          Criminals should be punished more severely.
# 16    The European Union should strengthen its secur...
# ...
